# %%
# import nltk
import pandas as pd
import numpy as np
# from ast import literal_eval

# %%
new_df = pd.read_pickle("clean_movie_dataset.pkl")

# %%
genre = pd.read_csv('genre_lst.csv')['genres'].tolist()

# %%
new_df['clean about'][0]
# Out:
# "['two', 'imprisoned', 'men', 'bond', 'number', 'years', 'finding', 'solace', 'eventual', 'redemption', 'acts', 'common', 'decency']"

# %%
genre
# Out:
# ['horror',
#  'sport',
#  'film-noir',
#  'war',
#  'adventure',
#  'history',
#  'action',
#  'crime',
#  'musical',
#  'music',
#  'comedy',
#  'romance',
#  'sci-fi',
#  'fantasy',
#  'animation',
#  'thriller',
#  'drama',
#  'western',
#  'family',
#  'biography',
#  'mystery']

# %%
lst = []

# %%
for g in genre:
  # if check[g].sum() >= 75:
  #   lst.append(True)
  # else:
  #   lst.append(False)
  lst.append(check[g].sum())

# %%
lst
# Out:
# [559,
#  119,
#  26,
#  99,
#  1009,
#  139,
#  1329,
#  1036,
#  64,
#  133,
#  1870,
#  849,
#  444,
#  413,
#  254,
#  850,
#  2583,
#  52,
#  279,
#  305,
#  516]

# %%
genre_lst_df = pd.DataFrame(genre,columns=['genres'])
genre_lst_df["more than 75 movies"] = lst

# %%
genre_lst_df
# Out:
#        genres  more than 75 movies  number of movies
# 0      horror                 True               559
# 1       sport                 True               119
# 2   film-noir                False                26
# 3         war                 True                99
# 4   adventure                 True              1009
# 5     history                 True               139
# 6      action                 True              1329
# 7       crime                 True              1036
# 8     musical                False                64
# 9       music                 True               133
# 10     comedy                 True              1870
# 11    romance                 True               849
# 12     sci-fi                 True               444
# 13    fantasy                 True               413
# 14  animation                 True               254
# 15   thriller                 True               850
# 16      drama                 True              2583
# ...

# %%
check[check['romance']]
# Out:
#                                                  poster  \
# 5     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 30    https://m.media-amazon.com/images/S/sash/4Fyxw...
# 53    https://m.media-amazon.com/images/S/sash/4Fyxw...
# 59    https://m.media-amazon.com/images/S/sash/4Fyxw...
# 67    https://m.media-amazon.com/images/S/sash/4Fyxw...
# ...                                                 ...
# 4922  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4924  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4930  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4941  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4953  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                       title certificate  runtime  \
# 5                              forrest gump          12  142 min
# 30                                  titanic          12  194 min
# 53    eternal sunshine of the spotless mind          15  108 min
# ...

# %%
genre_lst_df = pd.read_csv('genre_lst.csv')

# %%
genre_lst_df
# Out:
#     Unnamed: 0     genres  more than 75 movies  number of movies
# 0            0     horror                 True               559
# 1            1      sport                 True               119
# 2            2  film-noir                False                26
# 3            3        war                 True                99
# 4            4  adventure                 True              1009
# 5            5    history                 True               139
# 6            6     action                 True              1329
# 7            7      crime                 True              1036
# 8            8    musical                False                64
# 9            9      music                 True               133
# 10          10     comedy                 True              1870
# 11          11    romance                 True               849
# 12          12     sci-fi                 True               444
# ...

# %%
genre_lst_df[genre_lst_df['genres'] == 'horror']['more than 75 movies'].bool()
# Out:
# True

# %%
genre_lst_df.to_csv('genre_lst.csv')

# %%
genre_lst_df = pd.read_csv('genre_lst.csv')

# %%
genre_lst_df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
genre_lst_df
# Out:
#        genres  more than 75 movies  number of movies
# 0      horror                 True               559
# 1       sport                 True               119
# 2   film-noir                False                26
# 3         war                 True                99
# 4   adventure                 True              1009
# 5     history                 True               139
# 6      action                 True              1329
# 7       crime                 True              1036
# 8     musical                False                64
# 9       music                 True               133
# 10     comedy                 True              1870
# 11    romance                 True               849
# 12     sci-fi                 True               444
# 13    fantasy                 True               413
# 14  animation                 True               254
# 15   thriller                 True               850
# 16      drama                 True              2583
# ...

# %%
genre_lst_df[genre_lst_df['more than 75 movies'].tolist()]
# Out:
#        genres  more than 75 movies
# 0      horror                 True
# 1       sport                 True
# 3         war                 True
# 4   adventure                 True
# 5     history                 True
# 6      action                 True
# 7       crime                 True
# 9       music                 True
# 10     comedy                 True
# 11    romance                 True
# 12     sci-fi                 True
# 13    fantasy                 True
# 14  animation                 True
# 15   thriller                 True
# 16      drama                 True
# 18     family                 True
# 19  biography                 True
# 20    mystery                 True

# %%
(pd.read_csv('genre_lst.csv')['genres']).to_list()
# Out:
# ['horror',
#  'sport',
#  'film-noir',
#  'war',
#  'adventure',
#  'history',
#  'action',
#  'crime',
#  'musical',
#  'music',
#  'comedy',
#  'romance',
#  'sci-fi',
#  'fantasy',
#  'animation',
#  'thriller',
#  'drama',
#  'western',
#  'family',
#  'biography',
#  'mystery']

# %%
check = pd.read_pickle('clean_movie_dataset.pkl')

# %%
check['director'][5]
# Out:
# 'robert zemeckis'

# %%
movies_df.to_csv('clean_movie_dataset.csv')

# %%
movies_df
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0           0
# 1                1           1
# 2                2           2
# 3                3           3
# 4                4           4
# ...            ...         ...
# 4981          4981        4981
# 4982          4982        4982
# 4983          4983        4983
# 4984          4984        4984
# 4985          4985        4985
#
#                                                  poster  \
# 0     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4     https://m.media-amazon.com/images/S/sash/4Fyxw...
# ...                                                 ...
# 4981  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4982  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4983  https://m.media-amazon.com/images/S/sash/4Fyxw...
# ...

# %%
movies_df['genre'][1]
# Out:
# ['action', 'crime', 'drama']

# %%
movies_df.to_pickle("clean_movie_dataset.pkl",protocol=4)

# %%
for i in range(len(movies_df['genre'])):
  obj = movies_df['genre'][i]
  if type(obj) != float:
    movies_df['genre'][i] = obj.strip('][').split(', ')
# Out:
# e:\Anaconda3\envs\cs4300\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for i in range(len(movies_df['genre'])):
  obj = movies_df['genre'][i]
  if type(obj) != float:
    for j in range(len(obj)):
      movies_df['genre'][i][j] = eval(obj[j])

# %%
type(movies_df['genre'][1])
# Out:
# list

# %%
type(movies_df['genre'][1][0])
# Out:
# str

# %%
movies_df
# Out:
# 0          frank darabont
# 1       christopher nolan
# 2       christopher nolan
# 3           david fincher
# 4       quentin tarantino
#               ...
# 4981        stanley donen
# 4982       justin reardon
# 4983          john h. lee
# 4984          john waters
# 4985        robert altman
# Name: director, Length: 4986, dtype: object

# %%
for i in range(len(movies_df['genre'])):
  obj = movies_df['genre'][i]
  if type(obj) != float:
    for j in range(len(obj)):
      movies_df['genre'][i][j] = obj[j].strip()

# %%
genre_lst = ["horror",
 "crime",
 "western",
"film-noir",
"sci-fi",
"adventure",
"mystery",
 "thriller",
 "comedy",
 "romance",
 "mystery",
"family",
"animation",
"western",
 "biography",
"crime",
 "sport",
 "fantasy",
"action",
 "war",
"drama",
 "musical",
 "music",
 "history"
]

# %%
genre_lst_df.to_pickle('genre_lst.pkl')

# %%
a = a.to_list()

# %%
a
# Out:
# ['horror',
#  'sport',
#  'film-noir',
#  'war',
#  'adventure',
#  'history',
#  'action',
#  'crime',
#  'musical',
#  'music',
#  'comedy',
#  'romance',
#  'sci-fi',
#  'fantasy',
#  'animation',
#  'thriller',
#  'drama',
#  'western',
#  'family',
#  'biography',
#  'mystery']

# %%
genre_lst_df.to_csv('genre_lst.csv')

# %%
movies_df['director'] = movies_df['director'].str.lower()

# %%
movies_df
# Out:
#                      track_id  \
# 0      004s3t0ONYlzxII9PLgU6z
# 1      00chLpzhgVjxs1zKC9UScL
# 2      00cqd6ZsSkLZqGMlQCR0Zo
# 3      00emjlCv9azBN0fzuuyLqy
# 4      00f9VGHfQhAHMCQ2bSjg3D
# ...                       ...
# 13407  7zU9pcTnh6Q4nBnrg47Xz0
# 13408  7zxLkZbUxITHabPzGN8Xgc
# 13409  7zxRMhXxJMQCeDDg0rKAVo
# 13410  7zXzWCVuz7whIuYZyEAlxt
# 13411  7zye9v6B785eFWEFYs13C2
#
#                                               track_name  \
# 0                                           I Feel Alive
# 1                                                 Poison
# 2      Baby It's Cold Outside (feat. Christina Aguilera)
# 3                                             Dumb Litty
# 4                                                Soldier
# ...                                                  ...
# 13407  Bubble Butt (feat. Bruno Mars, 2 Chainz, Tyga ...
# 13408                                       Sick Feeling
# 13409                                           Some Way
# ...

# %%
movies_df[movies_df['track_name'] == 'The Passenger']
# Out:
#                      track_id     track_name               track_artist  \
# 3947   24FmdHoCr2jZGE6Z6dZbJT  The Passenger                   Iggy Pop
# 7241   3yP0cohcr97BUNJcgvmSVg  The Passenger                   Iggy Pop
# 11053  6EZDbjz2X5XzgIZCtbsrXh  The Passenger  Siouxsie and the Banshees
#
#                                                   lyrics  track_popularity  \
# 3947   ['i am a passenger', 'and', 'i ride and', 'i r...                45
# 7241   ['i am a passenger', 'and', 'i ride and', 'i r...                21
# 11053  ['i am the passenger', 'and', 'i ride and', 'i...                59
#
#                track_album_id  \
# 3947   5F79SWd4x7teHv5An2pqHQ
# 7241   7ynKEunH8LSit4TR3foMVC
# 11053  7kEqVGkLoruahp34YW16oe
#
#                                         track_album_name  \
# 3947                                       Lust For Life
# 7241                                       Lust For Life
# 11053  Through The Looking Glass (Remastered And Expa...
#
# ...

# %%
movies_df[movies_df['track_name'] == 'Do Or Die - Afrojack vs. THIRTY SECONDS TO MARS Remix']
# Out:
#                     track_id  \
# 4550  2hr7myxuDCoXsKyVfh4ue0
# 6294  3i4SQvUfK8Un3YkraZwkNr
#
#                                              track_name track_artist  \
# 4550  Do Or Die - Afrojack vs. THIRTY SECONDS TO MAR...     Afrojack
# 6294  Do Or Die - Afrojack vs. THIRTY SECONDS TO MAR...     Afrojack
#
#                                                  lyrics  track_popularity  \
# 4550  ['in the middle of the night when the angels s...                55
# 6294  ['in the middle of the night when the angels s...                 0
#
#               track_album_id           track_album_name  \
# 4550  7G1441qDQeERZDyMipQPE8  Forget The World (Deluxe)
# 6294  2V0QrN19MlIEwcuV4SEwfl          Do Or Die (Remix)
#
#      track_album_release_date  \
# 4550               2014-01-01
# 6294               2014-01-01
#
#                                           playlist_name  \
# 4550      Mix ElectroPop//ElectroHouse// DeepHouse 2020
# ...

# %%
for x in ['drama']:
  print(x)
# Out:
# drama

# %%
for x in set([g for lst in movies_df['genre'] for g in lst]):
  print(x)
# Out:
# horror
#  crime
#  horror
#  western
# film-noir
# sci-fi
# adventure
# a
# mystery
#  thriller
#  sci-fi
#  comedy
#  romance
#  mystery
# family
# animation
# western
#  biography
# crime
#  sport
# thriller
#  fantasy
# action
#  war
# drama
#  musical
#  film-noir
# romance
# comedy
# n
#  action
#  drama
# fantasy
#  music
#  history
#  adventure
#  family
# biography
# musical

# %%
movies_df.to_csv('clean_movie_dataset.csv')

# %%
print(movies_df[movies_df['director'].str.lower() == "x"].empty)
# Out:
# True

# %%
nltk.edit_distance(["apple","apple"], ['word','juice'])
# Out:
# 2

# %%
nltk.edit_distance("apple", 'word')
# Out:
# 5

# %%
nltk.edit_distance("apple", 'juice')
# Out:
# 4

# %%
for x in [1,2,3,4,5,6]:
  print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
min([1,2,34])
# Out:
# 1
